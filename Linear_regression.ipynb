# %% [markdown]
# <a href="https://colab.research.google.com/github/mail2chandanadasari-code/ML_LAB_2026-27/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
